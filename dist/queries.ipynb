# %% [markdown]
# #### load SQL extension

# %%
# %reload_ext sql

# %% [markdown]
# #### Connect to northwind db

# %%
# %sql sqlite:///northwind.db
# Out:
# 'Connected: @northwind.db'

# %% [markdown]
# #### test connection

# %%
# %%sql
# SELECT
#     FirstName,LastName
# FROM
#     Employees
# LIMIT
#     10;
# Out:
#  * sqlite:///northwind.db
# Done.
# [('Nancy', 'Davolio'),
#  ('Andrew', 'Fuller'),
#  ('Janet', 'Leverling'),
#  ('Margaret', 'Peacock'),
#  ('Steven', 'Buchanan'),
#  ('Michael', 'Suyama'),
#  ('Robert', 'King'),
#  ('Laura', 'Callahan'),
#  ('Anne', 'Dodsworth')]
